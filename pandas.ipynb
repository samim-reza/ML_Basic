# %%
import pandas as pd

# %%
df = pd.read_csv('titanic_train.csv')
df.head()
# Out:
#    passenger_id  pclass                                               name  \
# 0          1216       3                                 Smyth, Miss. Julia
# 1           699       3                                    Cacic, Mr. Luka
# 2          1267       3  Van Impe, Mrs. Jean Baptiste (Rosalie Paula Go...
# 3           449       2              Hocking, Mrs. Elizabeth (Eliza Needs)
# 4           576       2                                    Veal, Mr. James
#
#       sex   age  sibsp  parch  ticket     fare cabin embarked boat  body  \
# 0  female   NaN      0      0  335432   7.7333   NaN        Q   13   NaN
# 1    male  38.0      0      0  315089   8.6625   NaN        S  NaN   NaN
# 2  female  30.0      1      1  345773  24.1500   NaN        S  NaN   NaN
# 3  female  54.0      1      3   29105  23.0000   NaN        S    4   NaN
# 4    male  40.0      0      0   28221  13.0000   NaN        S  NaN   NaN
#
#                   home.dest  survived
# ...

# %%
df['age'].isnull().sum()
# Out:
# 174

# %%
df2 = df.copy()
df2['age'] = df['age'].fillna(int(df['age'].mean()))

# %%
# df2 = df2.drop('name',axis=1)
df2 = df2.drop('name',axis=1, inplace = True)

# %%
df2.head()
# Out:
#    passenger_id  pclass                                               name  \
# 0          1216       3                                 Smyth, Miss. Julia
# 1           699       3                                    Cacic, Mr. Luka
# 2          1267       3  Van Impe, Mrs. Jean Baptiste (Rosalie Paula Go...
# 3           449       2              Hocking, Mrs. Elizabeth (Eliza Needs)
# 4           576       2                                    Veal, Mr. James
#
#       sex   age  sibsp  parch  ticket     fare cabin embarked boat  body  \
# 0  female  29.0      0      0  335432   7.7333   NaN        Q   13   NaN
# 1    male  38.0      0      0  315089   8.6625   NaN        S  NaN   NaN
# 2  female  30.0      1      1  345773  24.1500   NaN        S  NaN   NaN
# 3  female  54.0      1      3   29105  23.0000   NaN        S    4   NaN
# 4    male  40.0      0      0   28221  13.0000   NaN        S  NaN   NaN
#
#                   home.dest  survived
# ...

# %%
# len(df2.columns)

# %%
#how to make pandas dataframe
import numpy as np
df_demo = pd.DataFrame(
    {
        'key1':['v1',np.nan,'v3'],
        'key2':['v1','v2', 'v3']
    }
)
df_demo
# Out:
#   key1 key2
# 0   v1   v1
# 1  NaN   v2
# 2   v3   v3

# %%
df2.info()
df2.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 850 entries, 0 to 849
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   passenger_id  850 non-null    int64
#  1   pclass        850 non-null    int64
#  2   name          850 non-null    object
#  3   sex           850 non-null    object
#  4   age           850 non-null    float64
#  5   sibsp         850 non-null    int64
#  6   parch         850 non-null    int64
#  7   ticket        850 non-null    object
#  8   fare          849 non-null    float64
#  9   cabin         191 non-null    object
#  10  embarked      849 non-null    object
#  11  boat          308 non-null    object
#  12  body          73 non-null     float64
#  13  home.dest     464 non-null    object
#  14  survived      850 non-null    int64
# dtypes: float64(3), int64(5), object(7)
# memory usage: 99.7+ KB
#        passenger_id     pclass         age       sibsp       parch  \
# ...

# %%
df2['age'].value_counts()
# Out:
# age
# 29.0000    193
# 18.0000     32
# 30.0000     30
# 24.0000     29
# 22.0000     28
#           ...
# 80.0000      1
# 0.4167       1
# 22.5000      1
# 40.5000      1
# 76.0000      1
# Name: count, Length: 88, dtype: int64

# %%
df2['name'] = ['a' for i in range(len(df2))]

# %%
df2
# Out:
#      passenger_id  pclass name     sex   age  sibsp  parch  \
# 0            1216       3    a  female  29.0      0      0
# 1             699       3    a    male  38.0      0      0
# 2            1267       3    a  female  30.0      1      1
# 3             449       2    a  female  54.0      1      3
# 4             576       2    a    male  40.0      0      0
# ..            ...     ...  ...     ...   ...    ...    ...
# 845           158       1    a    male  55.0      0      0
# 846           174       1    a    male  58.0      0      0
# 847           467       2    a  female  24.0      1      0
# 848          1112       3    a  female   3.0      1      1
# 849           425       2    a    male  52.0      0      0
#
#                  ticket     fare cabin embarked boat   body  \
# 0                335432   7.7333   NaN        Q   13    NaN
# 1                315089   8.6625   NaN        S  NaN    NaN
# 2                345773  24.1500   NaN        S  NaN    NaN
# ...

# %%
# Access a row in df2 by index, for example, the first row (index 0)
df2.loc[0]
# Out:
# passenger_id      1216
# pclass               3
# name                 a
# sex             female
# age               29.0
# sibsp                0
# parch                0
# ticket          335432
# fare            7.7333
# cabin              NaN
# embarked             Q
# boat                13
# body               NaN
# home.dest          NaN
# survived             1
# Name: 0, dtype: object

# %%
#search
def sear(value):
    if value == 'male':
        return 1
    return 0
df2['sex']=df2['sex'].apply(sear)
df2
# Out:
#      passenger_id  pclass name  sex   age  sibsp  parch              ticket  \
# 0            1216       3    a    0  29.0      0      0              335432
# 1             699       3    a    1  38.0      0      0              315089
# 2            1267       3    a    0  30.0      1      1              345773
# 3             449       2    a    0  54.0      1      3               29105
# 4             576       2    a    1  40.0      0      0               28221
# ..            ...     ...  ...  ...   ...    ...    ...                 ...
# 845           158       1    a    1  55.0      0      0                 680
# 846           174       1    a    1  58.0      0      0               11771
# 847           467       2    a    0  24.0      1      0              244367
# 848          1112       3    a    0   3.0      1      1  SOTON/O.Q. 3101315
# 849           425       2    a    1  52.0      0      0              250647
#
# ...

# %%
df2.drop('name',axis=1, inplace=True)

# %%
#encoding
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, OrdinalEncoder
le = LabelEncoder()

# %%
df2['sex'] = le.fit_transform(df2['sex'])

# %%
# df2.age_description.unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_16034/2025173264.py in ?()
# ----> 1 df2.age_description.unique()
#
# ~/.local/lib/python3.8/site-packages/pandas/core/generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'age_description'

# %%
ohe = OneHotEncoder()
encoded = ohe.fit_transform(df2[['sex']])
encoded
# Out:
# <850x2 sparse matrix of type '<class 'numpy.float64'>'
# 	with 850 stored elements in Compressed Sparse Row format>

# %%
ohe.get_feature_names_out()
# Out:
# array(['sex_0', 'sex_1'], dtype=object)

# %%
df_new = pd.DataFrame(encoded.toarray(), columns=ohe.get_feature_names_out())
